# %% [markdown]
# <a href="https://colab.research.google.com/github/taiyouedax1216-collab/ai-portfolio/blob/main/HR_Attrition_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **ざっと市場分析**

# %% [markdown]
# # **IT**
#
# ①IT業界規模2022-2023年:19.3兆円
#
# ②トレンド: DX
#
# ③売上高シェア
#
# ・日本
#
#     1.NTTデータ
#
#     2.NEC
#
#     3.富士通
#
#     4.日立製作所
#
#     5.野村総合研究所
#
#
# ・世界
#
#     アクセンチュア、IBM、TSC
#
#
# ④業界の特徴：多重下請け構造
#
# ⑤収益構造：
#
# ・URL: https://gyokai-search.com/3-jyoho.htm

# %% [markdown]
# # **コンサル**
#
# ①市場規模
#
# 世界：3,540億米ドル
#
# 日本：約1兆円-2兆円
#
# url: https://consulfree.com/blog/consul-market-size/
#
# ②トレンド
#
#   DX、クラウドサービスの拡大、グローバル化の促進、AIとデータ分析、サステナブルIT、リモートワーク支援、サイバーセキュリティ
#
#
#   日本でも「2025年の崖」と称される課題（老朽化・ブラックボックス化した既存システムを放置しDXが進まない場合、2025年以降に最大年12兆円の経済損失が生じる可能性）が警鐘として鳴らされ、レガシーシステム刷新とDX推進へのニーズが非常に高まっている
#
# url: https://shimo-tech-trail.com/
#
# ③主要プレイヤー
#
# ～世界～
#
#   ビッグ4　（デロイト トーマツ コンサルティング、PwCコンサルティング、EYストラテジー・アンド・コンサルティング、KPMGコンサルティング）
#
#   アクセンチュア
#
#   デロイト トーマツ コンサルティング（Deloitte）
#
#   PwCコンサルティング
#
#   KPMGコンサルティング
#
#   EY（アーンスト・アンド・ヤング）
#
#   IBM
#
#   キャップジェミニ（Capgemini）
#
# ～日本～
#
#   NTTデータ
#
#   野村総合研究所
#
#   アビームコンサルティング
#
#   ベイカレント・コンサルティング
#
#   日立コンサルティング
#
# url：https://consulfree.com/blog/it-consulting-firm/
#
# ④収益構造
#
# ITコンサル企業の収益は主にプロジェクトベースのコンサルティングフィーから構成される。基本的なビジネスモデルは「従業員（コンサルタント）の稼働時間 × スキルレート」する形で、プロジェクトに投入する人員数と期間に応じてクライアントに費用請求するもの。
#
# 契約上はプロジェクト遂行に要する工数に基づき月額料金を請求する形式
#
# →失敗してもお金が入る
#
#
# 料金体系には一部成果報酬型（成功フィー）を組み込む契約もありますが、その割合は限定的で、収益の大半は人月ベースのコンサルティング費用が占める
#
# url：https://www.axc.ne.jp/media/careertips/consul_business-model#:~:text=1
#
#
# ⑤ITコンサル企業によくある社内課題
#
# ・人材確保と定着率
#
# →高度な専門スキルを持つ優秀な人材の採用競争が激化しており、コンサル各社は人材獲得に苦心している。特にAI・クラウド・セキュリティ等の分野で人材不足が深刻で、必要な人員を確保すること自体が課題となっている。
#
# url: https://shimo-tech-trail.com/it-consultant-trend-143
#
#
# ・離職率の高さ
#
# →コンサルファームの年間離職率は概ね20%前後とも言われ、一般企業平均（14%程度）より高い水準にある。長時間労働やストレスフルなプロジェクトも多く、人材の流動が激しいため、優秀な人材をどう定着させ育成するかが常に課題となる。このため各社はリモートワーク導入や勤務柔軟化、研修・資格取得支援の充実など、社員の働きやすさ・成長支援に向けた施策を講じ始めている
#
# url:https://jprocareer.co.jp/consulting/consultingfirm-turnover/
#
#
#
# 大まかな業界分析からの仮説
#
# →コンサルティング業界ではかなりコンサルタントの負荷が大きいので以下のようなことを考えた
#
# 会社の福利厚生などに不満を持っている人が多いのではないか
#
#
# ストレスレベルなども高いのではないか
#
#
# ワークライフバランスの実現ができないのではないか

# %% [markdown]
# **EDA**

# %%
# !pip install japanize-matplotlib

# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/最終課題I社/data.csv  のコピー')
print(df.shape)
df.head()
# Out:
# (1470, 44)
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   41       Yes      Travel_Rarely                   Sales                 1
# 1   49        No  Travel_Frequently  Research & Development                 8
# 2   37       Yes      Travel_Rarely  Research & Development                 2
# 3   33        No  Travel_Frequently  Research & Development                 3
# 4   27        No      Travel_Rarely  Research & Development                 2
#
#    Education EducationField  EmployeeCount  EmployeeNumber  \
# 0          2  Life Sciences              1               1
# 1          1  Life Sciences              1               2
# 2          2          Other              1               4
# 3          4  Life Sciences              1               5
# 4          1        Medical              1               7
#
#    EnvironmentSatisfaction  ... RemoteWork  MonthlyIncome  StressRating  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 44 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   Department                1470 non-null   object
#  4   DistanceFromHome          1470 non-null   int64
#  5   Education                 1470 non-null   int64
#  6   EducationField            1470 non-null   object
#  7   EmployeeCount             1470 non-null   int64
#  8   EmployeeNumber            1470 non-null   int64
#  9   EnvironmentSatisfaction   1470 non-null   int64
#  10  Gender                    1470 non-null   object
#  11  PerformanceIndex          1470 non-null   int64
#  12  JobInvolvement            1470 non-null   int64
#  13  JobLevel                  1470 non-null   int64
# ...

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# PerformanceIndex             int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyAchievement           int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                     int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# StockOptionLevel             int64
# TotalWorkingYears            int64
# TrainingTimesLastYear        int64
# ...

# %% [markdown]
# Age	年齢
#
# Attrition	離職（退職の有無）
#
# BusinessTravel	出張頻度
#
# Department	部署
#
# DistanceFromHome	自宅からの距離
#
# Education	学歴
#
# EducationField	専攻分野
#
# EmployeeCount	従業員数
#
# EmployeeNumber	従業員番号
#
# EnvironmentSatisfaction	職場環境満足度
#
# Gender	性別
#
# PerformanceIndex	パフォーマンス指数
#
# JobInvolvement	仕事への関与度
#
# JobLevel	職位レベル
#
# JobRole	職務内容
#
# JobSatisfaction	仕事満足度
#
# MaritalStatus	婚姻状況
#
# MonthlyAchievement	月間成果
#
# NumCompaniesWorked	勤務した会社数
#
# Over18	18歳以上かどうか
#
# OverTime	残業の有無
#
# PerformanceRating	パフォーマンス評価
#
# RelationshipSatisfaction	人間関係満足度
#
# StandardHours	標準労働時間
#
# StockOptionLevel	ストックオプションレベル
#
# TotalWorkingYears	総就業年数
#
# TrainingTimesLastYear	昨年の研修回数
#
# WorkLifeBalance	ワークライフバランス
#
# YearsAtCompany	会社在籍年数
#
# YearsInCurrentRole	現職年数
#
# YearsSinceLastPromotion	最終昇進からの年数
#
# YearsWithCurrManager	現上司との勤務年数
#
# HowToEmploy	雇用形態
#
# Incentive	インセンティブ
#
# RemoteWork	リモートワークの有無
#
# MonthlyIncome	月収
#
# StressRating	ストレス評価
#
# WelfareBenefits	福利厚生
#
# InHouseFacility	社内施設利用
#
# ExternalFacility	社外施設利用
#
# ExtendedLeave	長期休暇の利用
#
# FlexibleWork	フレックスタイム制の有無
#
# StressSelfReported	自己申告によるストレス
#
# Year	年度

# %%
df.describe()
# Out:
#                Age  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.895238          9.236735     2.910204            1.0
# std       9.151321          8.129551     1.025259            0.0
# min      18.000000          1.000000     1.000000            1.0
# 25%      30.000000          2.000000     2.000000            1.0
# 50%      36.000000          7.000000     3.000000            1.0
# 75%      43.000000         14.000000     4.000000            1.0
# max      60.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction  PerformanceIndex  \
# count     1470.000000              1470.000000       1470.000000
# mean      1022.185034                 2.721769         65.891156
# std        602.769132                 1.093082         20.329428
# min          1.000000                 1.000000         30.000000
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# PerformanceIndex            0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyAchievement          0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# ...

# %%
df.select_dtypes(include=object)
# Out:
#      Attrition     BusinessTravel              Department EducationField  \
# 0          Yes      Travel_Rarely                   Sales  Life Sciences
# 1           No  Travel_Frequently  Research & Development  Life Sciences
# 2          Yes      Travel_Rarely  Research & Development          Other
# 3           No  Travel_Frequently  Research & Development  Life Sciences
# 4           No      Travel_Rarely  Research & Development        Medical
# ...        ...                ...                     ...            ...
# 1465        No  Travel_Frequently  Research & Development        Medical
# 1466        No      Travel_Rarely  Research & Development        Medical
# 1467        No      Travel_Rarely  Research & Development  Life Sciences
# 1468        No  Travel_Frequently                   Sales        Medical
# 1469        No      Travel_Rarely  Research & Development        Medical
#
#       Gender                    JobRole MaritalStatus Over18 HowToEmploy
# ...

# %% [markdown]
# 44個中9個がオブジェクト

# %%
df.select_dtypes(exclude=object)
# Out:
#       Age  DistanceFromHome  Education  EmployeeCount  EmployeeNumber  \
# 0      41                 1          2              1               1
# 1      49                 8          1              1               2
# 2      37                 2          2              1               4
# 3      33                 3          4              1               5
# 4      27                 2          1              1               7
# ...   ...               ...        ...            ...             ...
# 1465   36                23          2              1            2061
# 1466   39                 6          1              1            2062
# 1467   27                 4          3              1            2064
# 1468   49                 2          3              1            2065
# 1469   34                 8          3              1            2068
#
#       EnvironmentSatisfaction  PerformanceIndex  JobInvolvement  JobLevel  \
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeNumber',
#        'EnvironmentSatisfaction', 'Gender', 'PerformanceIndex',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyAchievement', 'NumCompaniesWorked', 'Over18',
#        'OverTime', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StandardHours', 'StockOptionLevel', 'TotalWorkingYears',
#        'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany',
#        'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager',
#        'HowToEmploy', 'Incentive', 'RemoteWork', 'MonthlyIncome',
#        'StressRating', 'WelfareBenefits', 'InHouseFacility',
#        'ExternalFacility', 'ExtendedLeave', 'FlexibleWork',
#        'StressSelfReported', 'Year'],
#       dtype='object')

# %% [markdown]
# Attrition（離職）をとりあえず目的変数とする

# %%
sns.countplot(data=df,x='Attrition')
plt.show()

# %%
sns.histplot(data=df, x='Age')
plt.show()

# %%
sns.histplot(data=df, x='Gender')
plt.show()

# %%
sns.countplot(data=df, x='JobSatisfaction')
plt.show()

# %%
sns.countplot(data=df, x='WorkLifeBalance')
plt.show()

# %%
sns.countplot(data=df, x='StressRating')
plt.show()

# %%
sns.countplot(data=df, x='ExtendedLeave')
plt.show()

# %%
sns.countplot(data=df, x='FlexibleWork')
plt.show()

# %%
sns.countplot(data=df, x='BusinessTravel',hue='Attrition')
plt.show()

# %%
sns.countplot(data=df, x='Education',hue='Attrition')
plt.show()

# %%
import japanize_matplotlib

# %%
f,ax = plt.subplots(1,2,figsize=(18,8))
df['Attrition'].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('離職率')
sns.countplot(data=df,x='Attrition',ax=ax[1])
ax[1].set_title('離職の有無')
plt.show()

# %% [markdown]
# 不均衡データではなさそう　離職率16.2%

# %%
# グラフ描画
f, ax = plt.subplots(1, 2, figsize=(18, 8))

# 円グラフ（離職率）
df['Attrition'].value_counts().plot.pie(
    autopct='%1.1f%%',
    ax=ax[0],
    shadow=True,
    textprops={'fontsize': 16}  # ← パーセンテージなどの文字サイズ
)
ax[0].set_title('離職率', fontsize=20)  # ← タイトルの文字サイズ

# 棒グラフ（離職の有無）
sns.countplot(data=df, x='Attrition', ax=ax[1])
ax[1].set_title('離職の有無', fontsize=20)  # ← タイトルの文字サイズ
ax[1].set_xlabel('離職', fontsize=16)      # x軸ラベル
ax[1].set_ylabel('人数', fontsize=16)      # y軸ラベル
ax[1].tick_params(labelsize=14)           # 軸目盛の文字サイズ

plt.show()

# %%
sns.countplot(x='StressRating',hue='Attrition',data=df)
plt.show()

# %%
sns.histplot(data=df, x='Age',hue='Attrition')
plt.show()

# %% [markdown]
# 若い人が辞めている？？

# %%
sns.countplot(x='Gender',hue='Attrition',data=df)
plt.show()

# %%
sns.countplot(x='ExtendedLeave',hue='Attrition',data=df)
plt.show()

# %% [markdown]
# 長期休暇を利用できていない人が辞めている？？

# %%
sns.countplot(x='ExtendedLeave',hue='Attrition',data=df)
plt.show()

# %%
sns.countplot(x='EnvironmentSatisfaction',hue='Attrition',data=df)
plt.show()

# %%
sns.countplot(x='JobSatisfaction',hue='Attrition',data=df)
plt.show()

# %%
sns.histplot(data=df, x='DistanceFromHome',hue='Attrition')
plt.show()

# %%
sns.histplot(data=df, x='TotalWorkingYears',hue='Attrition')
plt.show()

# %% [markdown]
# 10年以下でやめている人が多い、平均勤務年数が低い？？

# %%
sns.histplot(data=df, x='YearsAtCompany',hue='Attrition')
plt.show()

# %% [markdown]
# 10年以下でやめている人が多い、
# 平均勤務年数が低い？？　'YearsAtCompany'と'TotalWorkingYears'の違いがわからない

# %%
sns.histplot(data=df, x='YearsInCurrentRole',hue='Attrition')
plt.show()

# %% [markdown]
# 入って数年でやめている？　現在の役職が10年以上の人はほとんどやめていない

# %%
sns.histplot(data=df, x='YearsWithCurrManager',hue='Attrition')
plt.show()

# %% [markdown]
# 今の上司との年数が短い方が辞める？

# %%
sns.histplot(data=df, x='RemoteWork',hue='Attrition')
plt.show()

# %% [markdown]
# リモートワークできていない人は辞める？

# %%
sns.histplot(data=df, x='MonthlyIncome',hue='Attrition')
plt.show()

# %%
sns.countplot(data=df, x='StressRating',hue='Attrition')
plt.show()

# %%
sns.countplot(data=df, x='InHouseFacility',hue='Attrition')
plt.show()

# %%
sns.countplot(data=df, x='StressSelfReported',hue='Attrition')
plt.show()

# %%
sns.histplot(data=df, x='OverTime',hue='Attrition')
plt.show()

# %%
sns.histplot(data=df, x='DistanceFromHome',hue='Attrition')
plt.show()

# %%
sns.histplot(data=df, x='MonthlyAchievement',hue='Attrition')
plt.show()

# %%
sns.histplot(data=df, x='PerformanceIndex',hue='Attrition')
plt.show()

# %%
sns.histplot(data=df, x='Year',hue='Attrition')
plt.show()

# %%
df_numeric = df.select_dtypes(include=['number'])
sns.heatmap(df_numeric.corr(),annot=True,cmap='bwr',linewidths=0.2)
fig = plt.gcf()
fig.set_size_inches(10,8)
plt.show()

# %%
df_numeric.corr()
# Out:
#                                Age  DistanceFromHome  Education  \
# Age                       1.000000         -0.006831   0.214264
# DistanceFromHome         -0.006831          1.000000   0.024032
# Education                 0.214264          0.024032   1.000000
# EmployeeCount                  NaN               NaN        NaN
# EmployeeNumber           -0.011681          0.036927   0.041294
# EnvironmentSatisfaction   0.003549         -0.015335  -0.033242
# PerformanceIndex          0.021813          0.035245   0.018016
# JobInvolvement            0.028687          0.005647   0.040451
# JobLevel                  0.503812          0.005429   0.103415
# JobSatisfaction          -0.004506         -0.008773  -0.010132
# MonthlyAchievement        0.032322          0.021502  -0.019788
# NumCompaniesWorked        0.301392         -0.022008   0.125738
# OverTime                 -0.050908          0.005431  -0.031154
# PerformanceRating         0.035425          0.024528   0.012323
# ...

# %% [markdown]
# objectカラムを前処理する必要がある、その後にAttritionに対する相関を見た方がよさそう

# %% [markdown]
# 自動化EDAもやってみる

# %%
# Pandas-Profilingをインストール
#!pip install https://s3.ap-northeast-1.amazonaws.com/lecture-handouts.weblab/%E7%AC%AC5%E5%9B%9E/ydata-profiling-master.zip

# Pandas-Profilingの依存関係パッケージのダウングレード
#!pip install markupsafe==2.0.1

# %%
# 先ほどインストールしたPandas-Profilingをインポート
#from pandas_profiling import ProfileReport
# Pandas-ProfilingにパッケージされているProfileReport関数の引数に、EDAを行いたいDataFrame形式のデータを渡す。
#profile_df = ProfileReport(df, explorative=True)
# これを実行するとカレントディレクトリに可視化レポートのファイルが自動保存される。
#profile_df.to_file("profile_df.html")
# 可視化レポートを確認する。
#profile_df

# %% [markdown]
# EDAから平均継続年数が低いことや若い人が辞めていることがわかった。新卒で入ってきついから辞めているのではないか。また長期休暇をとれていない人も辞めている人が多い。この観点で2つの観点（平均継続年数と長期休暇）についてにフォーカスして四季報などを参考に市場分析をもう一度する
#
# 補足
# リモートワークできていない人は辞める？
# 今の上司との年数が短い方が辞める？
#
# あと離職率の平均をITコンサル(コンサル)と全体で比較

# %% [markdown]
# **市場分析2**

# %% [markdown]
# # ・離職率
#
# 一般企業：11.9%? 確認必要
#
# コンサル：大まかに20％程度
#
#
# 一般企業:https://www.mhlw.go.jp/toukei/itiran/roudou/koyou/doukou/23-2/dl/gaikyou.pdf
#
# コンサル: https://www.movin.co.jp/column/column8.html
#
# https://www.mhlw.go.jp/toukei/itiran/roudou/koyou/doukou/24-2/dl/kekka_gaiyo-02.pdf?utm_source=chatgpt.com
#
# https://www.dir.co.jp/report/consulting/pbo_analysis/20191204_021159.pdf
#
# # ・平均継続年数
#
# 一般企業：12.5年
#
# コンサル：3～6年
#
#
# 一般企業：https://www.roberthalf.com/jp/ja/insights/hiring-help/average-length-of-service
#
# 一般企業：https://hataractive.jp/useful/1685/
#
# コンサル：https://www.movin.co.jp/column/column8.html
#
# https://irbank.net/E32549/salary?utm_source=chatgpt.com
#
#
#
# # ・長期休暇
#
# 長期休暇取得率があまりなかったので有給休暇取得率を調べた。
#
# 全体： 62%  10日
#
# コンサル：64.2%  (学術研究，専門・技術サービス業という括りだと)
#
# DTC	63.0
#
# PwC	59.7
#
# EYSC	59.7
#
# KPMG	62.5
#
# 参照：openwork(2025年2月現在）
#
#
#
# ～一般企業と比較したコンサル業界の特徴～
#
# 一般企業と比べると、コンサル業界の有給休暇の取得方法にはいくつかの独自性があります。例えば、一般企業では継続的な業務の中で有給を取得するケースが多い一方、コンサル業界ではプロジェクト単位で仕事が区切られるため、プロジェクト間での休暇取得が可能になるケースが多いです。また、グローバルに展開している企業では、有給休暇に加えて長期休暇やリフレッシュ休暇のような福利厚生を提供している場合もあります。例えばマッキンゼーでは、「Take Time」というプログラムにより、半年ごとに数週間の休暇を取得することが可能です。これらの特徴は、有給休暇取得を取り巻く環境に独自の柔軟さをもたらしています。
#
# ～有給取得の現状：数字で見る実態～
#
# コンサル業界における有給休暇取得率には、企業やプロジェクトによりばらつきが見られます。例えば、PwCのように入社初年度から最大20日間の有給が付与される一方で、取得率そのものは個人差が大きいという声もあります。全社的な有給取得率は、頻繁に調査される数値の一つですが、必須取得日数である5日間の達成が認められる企業が増える一方で、全ての日数を消化する社員は一部に限られているのが実情です。また、企業の内部調査によれば、特に大規模プロジェクトや繁忙期には、取得が一時的に後回しになるケースも多いようです
#
#
#
# 全体:https://www.mhlw.go.jp/toukei/itiran/roudou/jikan/syurou/23/dl/gaikyou.pdf
#
# コンサル：https://www.kotora.jp/c/50939/#co-index-6
#
# コンサル：https://career-view.jp/consulting/consulting-big4/
#
# # ・リモートワーク、働き方
#
# 全国：2024年7月のテレワーク実施率は22.6％
#
# コンサル：60.4%
#
# →高い
#
# url:https://rc.persol-group.co.jp/news/202408221000.html?utm_source=chatgpt.com
#
# ・上司との関係→これは上司というよりもほかの要因で辞めるから結果的に上司との関係が短いだけかも

# %% [markdown]
# これらに加えて、四季報や業界図鑑などを確認！！

# %% [markdown]
# **EDA2**

# %%
from sklearn.preprocessing import StandardScaler, LabelEncoder
col = df.select_dtypes(include= object)
col = list(col.columns)

# LabelEncoderで変換
le = LabelEncoder()

for i in col:
  df[i] = le.fit_transform(df[i])

df.head()
# Out:
#    Age  Attrition  BusinessTravel  Department  DistanceFromHome  Education  \
# 0   41          1               2           2                 1          2
# 1   49          0               1           1                 8          1
# 2   37          1               2           1                 2          2
# 3   33          0               1           1                 3          4
# 4   27          0               2           1                 2          1
#
#    EducationField  EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  \
# 0               1              1               1                        2
# 1               1              1               2                        3
# 2               4              1               4                        4
# 3               1              1               5                        4
# 4               3              1               7                        1
#
#    ...  RemoteWork  MonthlyIncome  StressRating  WelfareBenefits  \
# ...

# %% [markdown]
# ランダムフォレスト

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
X = df.drop('Attrition', axis = 1)
y = df['Attrition']

X_train, X_valid, y_train, y_valid = train_test_split(X,y, test_size = 0.2, random_state=0)

# %%
rfc = RandomForestClassifier(max_depth=10, min_samples_leaf=10, n_jobs=-1, n_estimators=100,random_state=42)
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=10, min_samples_leaf=10, n_jobs=-1,
#                        random_state=42)

# %%
rfc = RandomForestClassifier(max_depth=10, min_samples_leaf=10, n_jobs=-1, n_estimators=100,random_state=42)
rfc.fit(X_train, y_train)
print('Train Score: {}'.format(round(rfc.score(X_train, y_train), 3)))
print(' Test Score: {}'.format(round(rfc.score(X_valid, y_valid), 3)))
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
y_pred = rfc.predict(X_valid)
print('AUC:', roc_auc_score(y_valid, rfc.predict_proba(X_valid)[:,1]))
# Out:
# Train Score: 0.875
#  Test Score: 0.823
# AUC: 0.7723765432098766

# %%
print('Train Score: {}'.format(round(rfc.score(X_train, y_train), 3)))
print(' Test Score: {}'.format(round(rfc.score(X_valid, y_valid), 3)))
# Out:
# Train Score: 0.875
#  Test Score: 0.823

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
y_pred = rfc.predict(X_valid)
print('AUC:', roc_auc_score(y_valid, rfc.predict_proba(X_valid)[:,1]))
# Out:
# AUC: 0.7723765432098766

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 特徴量重要度を取得して降順ソート
s = pd.Series(rfc.feature_importances_, index=X.columns)
s_sorted = s.sort_values(ascending=False)

# カラーマップで色を設定（例：'tab20'は最大20色）
colors = plt.cm.tab20(np.linspace(0, 1, len(s_sorted)))

# グラフ描画
plt.figure(figsize=(10, 12))
plt.barh(s_sorted.index, s_sorted.values, color=colors)
plt.title("Feature Importances", fontsize=14)
plt.xlabel("Importance", fontsize=12)
plt.ylabel("Features", fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %% [markdown]
# 離職確率を出す

# %% [markdown]
# 提案：やめるリスクが高い人に絞って効果的にアプローチができます。（教師なしでもできそう）あとやめる人の特徴がわかる。それによってどのようなアプローチをすればいいかがわかる
#
# →採用などにかかる費用をこれだけ減らせます（予測した人数×コスト）

# %% [markdown]
# https://www.persol-bd.co.jp/column/hrsolution/recruitment-cost/
#
# https://campus.doda.jp/enterprise/column/c35
#
# https://shushokumirai.recruit.co.jp/wp-content/uploads/2020/06/hakusyo2020_01-48_up-1.pdf

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# feature_importmnces_属性を取得
s1 = pd.Series(rfc.feature_importances_, index=X.columns)


import matplotlib.pyplot as plt

plt.figure(figsize=(10, 12))  # グラフ全体のサイズ調整（横×縦）

# 取得した値を降順に表示
s1.sort_values(ascending=False).plot.barh(color='C0')  # 横向きバーグラフ

plt.title("Feature Importances", fontsize=14)
plt.xlabel("Importance", fontsize=12)
plt.ylabel("Features", fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.gca().invert_yaxis()  # 重要度の高い順に上に表示

plt.tight_layout()  # はみ出さないように自動調整
plt.show()

# %% [markdown]
# **仮説の真偽検証**
#
# EDAの結果から、若くて勤続年数が短い人ほど辞めている傾向が見られました。
# 特に「年齢（Age）」の重要度が高く、新卒で入社した人が仕事に慣れる前に辞めてしまっている可能性がありそうです。
#
# また、「長期休暇（ExtendedLeave）」を取得していない人の方が辞めやすい傾向があり、ちゃんと休めていないことが影響しているかもしれません。
#
# 「リモートワーク（RemoteWork）」ができていない人も辞めやすくなっているようです。柔軟な働き方ができないことが離職に関係している可能性があります。
#
# さらに、「今の上司と一緒に働いている年数（YearsWithCurrManager）」が短い人も離職率が高いようです。ただしこれは、若い人ほど上司との関係がまだ浅い＝そのまま辞めてしまっている、という因果の関係かもしれません。
#
#
# **新たな発見**
#
# 1. 「インセンティブ（Incentive）」が高い影響力を持っている
# 仮説：インセンティブ制度の有無や金額が離職率に影響している
#
# 補足：給与とは別に、成果報酬やボーナス制度がモチベーション維持に効果的かもしれません。
#
# 2. 「StressRating」が高く、自己申告の「StressSelfReported」は低い
# 仮説：ストレスの客観評価と自己申告では乖離がある
#
# 解釈：
#
# 「StressRating」：会社側で測定されたストレス指標 → 離職に強く影響
#
# 「StressSelfReported」：本人が申告したストレス → あまり説明力がない
#
# 考察：従業員は本当のストレスを言えない／気づいていない可能性
#
# 3. 「JobLevel」や「MonthlyIncome」も比較的高い
# 仮説：役職や給与の水準が、離職に抑止効果を与えている可能性
#
# 考察：
#
# 若手層が辞めているなら当然かもしれないが、
#
# 高い給与でも離職する場合もある（他要因との相互作用が重要）
#
# 4. 「YearsWithCurrManager」がわりと高い
# 補足：前回の仮説を補強。
#
# 仮説：上司との関係性が、離職の抑止・促進に影響している
#
# もし上司交代が多い部署なら、そこが離職多発ポイントかも。
#
# 5. 「JobRole」「PerformanceIndex」「MonthlyAchievement」は中程度
# 仮説：成果や業務内容自体よりも、環境や待遇面の方が影響が大きい
#
# 解釈：
#
# 自分の成果よりも、ストレス・年齢・環境が辞める理由になっている
#
# 「働きがい」より「働きやすさ」の方が重要視されている可能性

# %% [markdown]
# **特徴量重要度が高いとされたもの**

# %% [markdown]
# age

# %%
print('mean:',df.groupby(['Attrition'])['Age'].mean())
print('median:', df.groupby(['Attrition'])['Age'].median())
# Out:
# mean: Attrition
# 0    37.533279
# 1    33.592437
# Name: Age, dtype: float64
# median: Attrition
# 0    36.0
# 1    32.0
# Name: Age, dtype: float64

# %% [markdown]
# 離職する人の方が若め、かつ年配の社員が少ないのも問題点

# %%
df.groupby('Attrition')['Age'].plot.hist(bins=20, alpha=0.5, legend=True)
# Out:
# Attrition
# 0    Axes(0.125,0.11;0.775x0.77)
# 1    Axes(0.125,0.11;0.775x0.77)
# Name: Age, dtype: object

# %%
from scipy import stats
s, pvalue = stats.mannwhitneyu(df[df["Attrition"]==1]["Age"]
                , df[df["Attrition"]==0]["Age"]
                ,alternative='two-sided')
pvalue < 0.05
# Out:
# np.True_

# %% [markdown]
# TotalWorkingYears 事前のEDAでもわかってた
#
# →（総職歴年数）
# 社会人として働き始めてからの 全ての職歴の合計年数。

# %%
print('mean:',df.groupby(['Attrition'])['TotalWorkingYears'].mean())
# Out:
# mean: Attrition
# 0    11.851461
# 1     8.159664
# Name: TotalWorkingYears, dtype: float64

# %%
df.groupby('Attrition')['TotalWorkingYears'].plot.hist(bins=20, alpha=0.5, legend=True)
# Out:
# Attrition
# 0    Axes(0.125,0.11;0.775x0.77)
# 1    Axes(0.125,0.11;0.775x0.77)
# Name: TotalWorkingYears, dtype: object

# %%
from scipy import stats
s, pvalue = stats.mannwhitneyu(df[df["Attrition"]==1]["TotalWorkingYears"]
                , df[df["Attrition"]==0]["TotalWorkingYears"]
                ,alternative='two-sided')
pvalue < 0.05
# Out:
# np.True_

# %% [markdown]
# インセンティブ

# %%
print('mean:',df.groupby(['Attrition'])['Incentive'].mean())
# Out:
# mean: Attrition
# 0    1276.359578
# 1     451.890756
# Name: Incentive, dtype: float64

# %% [markdown]
# インセンティブが低い→これは新卒だからの可能性がある

# %%
df.groupby(['Attrition'])['Incentive'].plot.hist(bins=20, alpha=0.5, legend=True)
# Out:
# Attrition
# 0    Axes(0.125,0.11;0.775x0.77)
# 1    Axes(0.125,0.11;0.775x0.77)
# Name: Incentive, dtype: object

# %%
from scipy import stats
s, pvalue = stats.mannwhitneyu(df[df["Attrition"]==1]["Incentive"]
                , df[df["Attrition"]==0]["Incentive"]
                ,alternative='two-sided')
pvalue < 0.05
# Out:
# np.True_

# %% [markdown]
# YearsAtCompony
#
# →現在の会社に勤めている年数のみ。

# %%
print('mean:',df.groupby(['Attrition'])['YearsAtCompany'].mean())
print('median:',df.groupby(['Attrition'])['YearsAtCompany'].median())
# Out:
# mean: Attrition
# 0    7.392045
# 1    5.021008
# Name: YearsAtCompany, dtype: float64
# median: Attrition
# 0    6.0
# 1    3.0
# Name: YearsAtCompany, dtype: float64

# %% [markdown]
# 離職している人の方が高い

# %%
df.groupby(['Attrition'])['YearsAtCompany'].plot.hist(bins=20, alpha=0.5, legend=True)
# Out:
# Attrition
# 0    Axes(0.125,0.11;0.775x0.77)
# 1    Axes(0.125,0.11;0.775x0.77)
# Name: YearsAtCompany, dtype: object

# %%
from scipy import stats
s, pvalue = stats.mannwhitneyu(df[df["Attrition"]==1]["YearsAtCompany"]
                , df[df["Attrition"]==0]["YearsAtCompany"]
                ,alternative='two-sided')
pvalue < 0.05
# Out:
# np.True_

# %%
sns.countplot(data=df, x='StressSelfReported', hue='Attrition')
plt.show()

# %%
print('mean:',df.groupby(['Attrition'])['StressRating'].mean())
# Out:
# mean: Attrition
# 0    2.427760
# 1    2.869748
# Name: StressRating, dtype: float64

# %%
sns.countplot(data=df, x='StressRating', hue='Attrition')
plt.show()

# %%
import pandas as pd

# StressRatingでグループ化し、それぞれの離職率（Attritionの平均値）を計算
turnover_rate_by_stress = df.groupby('StressRating')['Attrition'].mean()

print("--- ストレス評価ごとの離職率 ---")
# 結果をパーセンテージで表示
for level, rate in turnover_rate_by_stress.items():
    print(f"ストレス評価 {level}: {rate:.1%}")
# Out:
# --- ストレス評価ごとの離職率 ---
# ストレス評価 1: 14.8%
# ストレス評価 2: 12.6%
# ストレス評価 3: 11.8%
# ストレス評価 4: 39.2%
# ストレス評価 5: 67.9%

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.ticker import PercentFormatter

# 離職率のデータを計算
turnover_rate_by_stress = df.groupby('StressRating')['Attrition'].mean()

# グラフの作成
fig, ax1 = plt.subplots(figsize=(10, 6))

# 1. 棒グラフ（人数）を描画 (左側のY軸)
sns.countplot(data=df, x='StressRating', hue='Attrition', ax=ax1)
ax1.set_ylabel('人数', fontsize=14)
ax1.set_xlabel('ストレス評価', fontsize=14)
ax1.legend(title='離職有無')

# 2. 折れ線グラフ（離職率）を描画するための第二のY軸を作成
ax2 = ax1.twinx()

# 3. 折れ線グラフを第二のY軸に描画
ax2.plot(turnover_rate_by_stress.index - 1, # x軸の位置を調整
         turnover_rate_by_stress.values,
         color='red',
         marker='o',
         linestyle='--',
         label='離職率')

# 第二のY軸の書式をパーセントに設定
ax2.yaxis.set_major_formatter(PercentFormatter(1.0))
ax2.set_ylabel('離職率', fontsize=14, color='red')
ax2.tick_params(axis='y', labelcolor='red')
ax2.set_ylim(0, 1) # Y軸の範囲を0%から100%に設定

# 凡例を一つにまとめる
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='upper right')
ax1.get_legend().remove() # 元の凡例は削除


plt.show()

# %%
import pandas as pd
#  1. インセンティブの平均値と比較

# グループごとの平均値を計算
incentive_means = df.groupby('Attrition')['Incentive'].mean()

# 離職者と残留者の平均値を取得
mean_leaver_incentive = incentive_means[1]
mean_stayer_incentive = incentive_means[0]

# 比率を計算
ratio = mean_leaver_incentive / mean_stayer_incentive

print("インセンティブ分析")
print(f"残留者の平均インセンティブ: {mean_stayer_incentive: .1f}")
print(f"離職者の平均インセンティブ: {mean_leaver_incentive: .1f}")
print(f"離職者のインセンティブは残留者の約 {ratio:.2f} 倍 (約3分の1)")
print("-" * 25)


#  2. 高ストレス層（評価4以上）の離職率

# ストレス評価が4以上の社員データに絞り込む
high_stress_df = df[df['StressRating'] >= 4]

# 絞り込んだデータの中での離職率（Attrition列の平均値が離職率になる）を計算
high_stress_turnover_rate = high_stress_df['Attrition'].mean()

print("\n--- 高ストレス層の離職率分析 ---")
print(f"ストレス評価が4以上の社員の離職率: {high_stress_turnover_rate:.1%}")
print("-" * 25)


# ストレス評価全体の平均値
stress_means = df.groupby('Attrition')['StressRating'].mean()
print("\n--- ストレス評価 全体の平均値 ---")
print(f"残留者の平均ストレス評価: {stress_means[0]:.2f}")
print(f"離職者の平均ストレス評価: {stress_means[1]:.2f}")
print("-" * 25)
# Out:
# インセンティブ分析
# 残留者の平均インセンティブ:  1276.4
# 離職者の平均インセンティブ:  451.9
# 離職者のインセンティブは残留者の約 0.35 倍 (約3分の1)
# -------------------------
#
# --- 高ストレス層の離職率分析 ---
# ストレス評価が4以上の社員の離職率: 43.9%
# -------------------------
#
# --- ストレス評価 全体の平均値 ---
# 残留者の平均ストレス評価: 2.43
# 離職者の平均ストレス評価: 2.87
# -------------------------

# %% [markdown]
# どの観点から提案するかがいくつかある
#
# ①若い人の離職を防ぐ、その会社での継続年数を伸ばす　Age、YearsAtCompony(TotalWokingYears)
#
# →若い人の離職を防ぐことで採用コストを減らせることを提案
#
# ②待遇改善 Incentive　StressRating　MonthlyIncome
#
# ③働き方　RemoteWorkなど
#
# 一旦①をメインとしてやる
#
# https://chatgpt.com/share/685947eb-db64-800e-9e76-ac0798c7b566

# %% [markdown]
# ・若手層の離職率も調べる　コンサルや全体
#
# ・入社年度が2023と2024の2つある　これも考慮するべきかも
#
# ・あとは分析の際に若手の離職を防ぐために若手のみに絞ってやったほうがいいかも
#
# →中央値ベースで定義
# 離職者の中央値32歳をベースに「若手＝32歳以下」と定義
#
# メリット：データに忠実な定義
#
# デメリット：やや保守的で幅が狭い可能性
#
# ・年配社員の割合が少ない
#
# →これによるデメリットを考える
#
# →また解決できたことによるメリット（金銭的）
#
# ・逆に働き続けることができている社員はどんな人なのかを調べる
#
# →人事評価が高い人は働き続けられる？？
#
# ・コンサル業界は人が重要だから、ベテランがいれば受注率や売り上げが上がるんではないか（若い人が辞めているからベテランが少ない）
#
# ・課題：若手が辞める＋ベテランが少ない
#
# →これを数値で示すには？
#
# ・サービス：毎月社員ごとの離職確率を出して、その中から重点的にフォローすべき人を伝える、それをやることでどのくらい減らせます
#
# ・教師なし学習で課題を見つける
#
# ～疑問点～
# 全データが1470あってそのデータ全てに対して離職確率を出したいが、モデル構築の際に使った訓練データも含めた全データに対して離職確率を出すのはいいんですか？

# %% [markdown]
# 若手が辞める、ベテランが少ない

# %%
# 年齢を5歳ごとにビン分割
df['AgeBin'] = pd.cut(df['Age'], bins=[18, 24, 30, 36, 42, 48, 54, 60])

# 各年齢ビンごとの離職率を算出
agebin_attrition = df.groupby('AgeBin')['Attrition'].mean()

print(agebin_attrition)
# Out:
# AgeBin
# (18, 24]    0.382022
# (24, 30]    0.217241
# (30, 36]    0.159036
# (36, 42]    0.096220
# (42, 48]    0.094972
# (48, 54]    0.117188
# (54, 60]    0.157143
# Name: Attrition, dtype: float64
# /tmp/ipython-input-176-50477150.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agebin_attrition = df.groupby('AgeBin')['Attrition'].mean()

# %%
print(df['AgeBin'].value_counts(normalize=True))
# Out:
# AgeBin
# (30, 36]    0.283858
# (36, 42]    0.199042
# (24, 30]    0.198358
# (42, 48]    0.122435
# (48, 54]    0.087551
# (18, 24]    0.060876
# (54, 60]    0.047880
# Name: proportion, dtype: float64

# %%
df['YearsAtCompany'].hist(bins=20)
plt.xlabel("year")
plt.ylabel("number")
plt.show()

# %%
df['TenureGroup'] = pd.cut(df['YearsAtCompany'], bins=[0, 3, 7, 10, 40],
                           labels=['Junior (≤3 yrs)', 'Mid-level (3–7 yrs)', 'Senior Candidate (7–10 yrs)', 'Veteran (10+ yrs)'])

print(df['TenureGroup'].value_counts())

print(df['TenureGroup'].value_counts(normalize=True))

print(df.groupby('TenureGroup')['Attrition'].mean())
# Out:
# TenureGroup
# Mid-level (3–7 yrs)            473
# Junior (≤3 yrs)                424
# Senior Candidate (7–10 yrs)    282
# Veteran (10+ yrs)              247
# Name: count, dtype: int64
# TenureGroup
# Mid-level (3–7 yrs)            0.331697
# Junior (≤3 yrs)                0.297335
# Senior Candidate (7–10 yrs)    0.197756
# Veteran (10+ yrs)              0.173212
# Name: proportion, dtype: float64
# TenureGroup
# Junior (≤3 yrs)                0.247642
# Mid-level (3–7 yrs)            0.135307
# Senior Candidate (7–10 yrs)    0.127660
# Veteran (10+ yrs)              0.068826
# Name: Attrition, dtype: float64
# /tmp/ipython-input-179-2224972987.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   print(df.groupby('TenureGroup')['Attrition'].mean())

# %% [markdown]
# **全データに対しての離職確率を出すためのモデルをつくる**

# %%
# 学習データと検証データを結合
X_full = pd.concat([X_train, X_valid])
y_full = pd.concat([y_train, y_valid])

# モデル再学習
rfc_full = RandomForestClassifier(max_depth=10, min_samples_leaf=10, n_jobs=-1,
                                  n_estimators=100, random_state=42)
rfc_full.fit(X_full, y_full)
# Out:
# RandomForestClassifier(max_depth=10, min_samples_leaf=10, n_jobs=-1,
#                        random_state=42)

# %%
# 離職確率（= Attritionが1の確率）を算出
df['AttritionProba'] = rfc_full.predict_proba(df.drop(columns=['Attrition', 'AgeBin','TenureGroup']))[:, 1]

# %%
df
# Out:
#       Age  Attrition  BusinessTravel  Department  DistanceFromHome  Education  \
# 0      41          1               2           2                 1          2
# 1      49          0               1           1                 8          1
# 2      37          1               2           1                 2          2
# 3      33          0               1           1                 3          4
# 4      27          0               2           1                 2          1
# ...   ...        ...             ...         ...               ...        ...
# 1465   36          0               1           1                23          2
# 1466   39          0               2           1                 6          1
# 1467   27          0               2           1                 4          3
# 1468   49          0               1           2                 2          3
# 1469   34          0               2           1                 8          3
#
# ...

# %% [markdown]
#  ①「過去の離職率から閾値を決める」方法（例：16%離職していた場合）
#
#  例えば過去に全体の16%が離職していたとすれば：
#
# 離職確率が高い人 ≒ 上位16%程度と仮定して quantile(0.84) を基準にする
#
# →「過去の実績と整合性がある」ので、人事部門にも説明しやすい
#
# これは、過去の離職傾向と同程度の母数を対象とすることで、
# ・ 対応リソースの過不足を防ぐ
# ・ 実績と整合性のある分析基準を採用する
# といった点で、現場にとっても受け入れやすい運用設計となります。

# %%
# AttritionProbaの上位16%を抽出
threshold_16pct = df['AttritionProba'].quantile(0.84)
high_risk_16pct = df[df['AttritionProba'] >= threshold_16pct]

print(f'閾値（上位16%）: {threshold_16pct:.3f}')
print(f'該当者数: {len(high_risk_16pct)}人')
# Out:
# 閾値（上位16%）: 0.269
# 該当者数: 236人

# %%
from sklearn.metrics import precision_recall_curve, f1_score
import numpy as np

# 検証用データ（valid）での予測確率と正解ラベルを使う
probas = rfc.predict_proba(X_valid)[:, 1]
precisions, recalls, thresholds = precision_recall_curve(y_valid, probas)

# 各閾値に対してF1スコアを計算
f1_scores = 2 * (precisions * recalls) / (precisions + recalls + 1e-10)  # 0除算回避の微調整
best_idx = np.argmax(f1_scores)
best_threshold = thresholds[best_idx]

print(f'F1スコア最大の閾値: {best_threshold:.3f}')
print(f'最大F1スコア: {f1_scores[best_idx]:.3f}')
# Out:
# F1スコア最大の閾値: 0.227
# 最大F1スコア: 0.579

# %% [markdown]
# ②「F1スコア最大化の閾値を探す」
#
# 補足：この閾値を使うことの説明（提案時に使える）
#
# モデルの予測結果に対して、**Precision（誤検出の少なさ）とRecall（取りこぼしの少なさ）**を最もバランス良く両立する基準を採用しました。この閾値を用いることで、対応すべき対象を明確にしつつ、誤対応のリスクを最小限に抑えることができます

# %%
df['HighRisk_F1'] = (df['AttritionProba'] >= best_threshold).astype(int)

# 該当者の確認
high_risk_f1 = df[df['HighRisk_F1'] == 1]
print(f'F1閾値に基づくリスク者数: {len(high_risk_f1)}人')
# Out:
# F1閾値に基づくリスク者数: 313人

# %% [markdown]
# 「本分析では、2つの基準で離職リスクの高い従業員を抽出しています」
#
# ① 実績ベース（上位16%）
# 　→ 過去の離職率に整合したターゲティングが可能。人事部に納得されやすい。
#
# ② 精度ベース（F1最大閾値）
# 　→ 離職者をできるだけ取りこぼさず、誤検出も最小限に抑える最適な判別境界。
#
# 両者を比較しながら、コストや対応可能人数に応じて最終的な対象者を決定することを推奨します
